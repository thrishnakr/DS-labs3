# %%
pip install git+https://github.com/alirezamika/autoscraper.git
# Out:
# ...
#   Cloning https://github.com/alirezamika/autoscraper.git to /tmp/pip-req-build-7lnmdttv
#   Running command git clone -q https://github.com/alirezamika/autoscraper.git /tmp/pip-req-build-7lnmdttv
# ...
#   Created wheel for autoscraper: filename=autoscraper-1.1.12-py3-none-any.whl size=10048 sha256=27610afa089c981274442469460e49b37380f24c9775a1b60d10b929e117ecb1
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ibusa6mj/wheels/31/9d/56/6263a49f4fc2b82138579d99b7303489c482c89acbaef59326
# Successfully built autoscraper
# ...

# %%
pip install autoscraper

# %%
from autoscraper import AutoScraper

# %%
url="https://www.flipkart.com/mobiles/~cs-5efeoyuede/pr?sid=tyy%2C4io&collection-tab-name=vivo+T1+5g&param=12411221&otracker=hp_bannerads_3_3.bannerAdCard.BANNERADS_Cat_mob_HPW_Vivo_T1_Sale%2Bis%2Bon_W2096VKGPXJS"
wanted_list1 = ['vivo T1 5G (Starlight Black, 128 GB)']
wanted_list2 = ['₹15,990']

scraper = AutoScraper()
result = scraper.build(url, wanted_list1)
result1 = scraper.build(url, wanted_list2)
print(result)
print(result1)
# Out:
# ['vivo T1 5G (Starlight Black, 128 GB)', 'vivo T1 5G (Rainbow Fantasy, 128 GB)']
# ['₹16,990', '₹15,990', '₹19,990']

# %%
url="https://www.flipkart.com/mobiles/~cs-5efeoyuede/pr?sid=tyy%2C4io&collection-tab-name=vivo+T1+5g&param=12411221&otracker=hp_bannerads_3_3.bannerAdCard.BANNERADS_Cat_mob_HPW_Vivo_T1_Sale%2Bis%2Bon_W2096VKGPXJS"
wanted_list1 = ['vivo T1 5G (Starlight Black, 128 GB)','₹15,990']

scraper = AutoScraper()
result = scraper.build(url, wanted_list1)
print(result)
# Out:
# ['vivo T1 5G (Starlight Black, 128 GB)', 'vivo T1 5G (Rainbow Fantasy, 128 GB)', '₹16,990', '₹15,990', '₹19,990']
